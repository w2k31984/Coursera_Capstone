# %% [markdown]
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDS0701ESCoursera21685115-2022-01-01"><img src = "https://ibm.box.com/shared/static/9gegpsmnsoo25ikkbl4qzlvlyjbgxs5x.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Cómo usar la API de FourSquare con Python</font></h1>

# %% [markdown]
# ## Introducción
#
# En este laboratorio usted aprenderá detalladamente a realizar llamadas a la API de FourSquare con distintos propositos. Aprenderá a construir una URL para enviar peticiones a la API para buscar lugares específicos, explorar un sitio en particular, un usuario de FourSquare o alguna referencia geografica, además, podrá obtener los lugares de moda alrededor de alguna locación. También aprederá a usar la librería de visualización Folium para ver los resultados.

# %% [markdown]
# ## Indice
#
# 1.  <a href="https://#item1">Función de Busqueda de la API de Foursquare</a>
# 2.  <a href="https://#item2">Explorar un Lugar</a>
# 3.  <a href="https://#item3">Explorar un Usuario</a>
# 4.  <a href="https://#item4">Función de Exploración de la API de Foursquare</a>
# 5.  <a href="https://#item5">Obtener Lugares de Moda</a>

# %% [markdown]
# ### Importar las librerías necesarias

# %%
import requests # librería para manejar las solicitudes
import pandas as pd # librería para análisis de datos
import numpy as np # librería para manejar datos vectorizados
import random # librería para generar números aleatorios


# !pip install geopy
from geopy.geocoders import Nominatim # módulo para convertir una dirección en valores de latitud y longitud 

# librerías para mostrar imágenes 
from IPython.display import Image 
from IPython.core.display import HTML 
    
# librería para convertir un archivo json en un dataframe pandas
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # librería para graficar 

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76117 sha256=cfaa5bb542d4f20065e6fd74a72ae61ab07981c7bbec10db8ba8a7e759affdfa
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/26/e2/90/e29b0a163b7ca7737dd33fc1ad742b38ff55963d8220013134
# Successfully built folium
# ...
#   Attempting uninstall: folium
#     Found existing installation: folium 0.11.0
#     Uninstalling folium-0.11.0:
#       Successfully uninstalled folium-0.11.0
# ...
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Definir la Versión y Credenciales de FourSquare

# %% [markdown]
# ##### Asegúrese de haber creado una cuenta de desarrollador en FourSquare con las credenciales apropiadas

# %%
CLIENT_ID = 'JH4PNBUYQL4VQOVJNTCSWLFDQBPNVZTSWKC5UTWXNKNJMH20' # su ID de Foursquare
CLIENT_SECRET = 'KIP3WV5SAR3G2XNAKEVKKAXFRK2KRWYM1XEF4CPGCJYWLMA5' # su Secreto de Cliente de Foursquare
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: JH4PNBUYQL4VQOVJNTCSWLFDQBPNVZTSWKC5UTWXNKNJMH20
# CLIENT_SECRET:KIP3WV5SAR3G2XNAKEVKKAXFRK2KRWYM1XEF4CPGCJYWLMA5

# %% [markdown]
# #### Vamos a suponer que usted esta hospedado en el hotel Conrad. Empecemos por convertir la dirección del hotel en valores de coordenadas dadas por la latitud y la longitud.

# %% [markdown]
# Para definir una instancia del geocoder necesitamos definir un user_agent. Nombraremos a nuestro agente <em>foursquare_agent</em> de la siguiente forma.

# %%
address = '102 North End Ave, New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7149555 -74.0153365

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Búsqueda por categoría de un lugar específico
#
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# #### Supongamos que es la hora de comer y usted desea comida italiana. Vamos a definir una consulta para buscar comida italiana dentro de un radio de 500 metros del hotel Conrad.

# %%
search_query = 'Italian'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
import requests

url = "https://api.foursquare.com/v3/places/nearby?ll=40.7149555%2C-74.0153365&query=%27Italian%27&limit=30"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3PmNUkK/HGoNLTZkiM0BIDkh3pNX86r6AZmdOTyjmG5U="
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"results":[{"fsq_id":"4a4560a7f964a5201aa81fe3","categories":[{"id":13064,"name":"Pizzeria","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/pizza_","suffix":".png"}},{"id":13236,"name":"Italian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"distance":1074,"geocodes":{"main":{"latitude":40.707324,"longitude":-74.007057},"roof":{"latitude":40.707324,"longitude":-74.007057}},"link":"/v3/places/4a4560a7f964a5201aa81fe3","location":{"address":"2 Gold St","census_block":"360610015024001","country":"US","cross_street":"at Maiden Ln.","dma":"New York","formatted_address":"2 Gold St (at Maiden Ln.), New York, NY 10038","locality":"New York","neighborhood":["City Hall"],"postcode":"10038","region":"NY"},"name":"Harry's Italian Pizza Bar","related_places":{},"timezone":"America/New_York"},{"fsq_id":"528bf16711d2b7722da6b51c","categories":[{"id":13002,"name":"Bakery","icon":{"prefix":"https://ss3.4sqi.net/img/cat
# ...

# %%
#Visualizando la respuesta como un Json
print(response.json())
# Out:
# {'results': [{'fsq_id': '4a4560a7f964a5201aa81fe3', 'categories': [{'id': 13064, 'name': 'Pizzeria', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_', 'suffix': '.png'}}, {'id': 13236, 'name': 'Italian Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}}], 'chains': [], 'distance': 1074, 'geocodes': {'main': {'latitude': 40.707324, 'longitude': -74.007057}, 'roof': {'latitude': 40.707324, 'longitude': -74.007057}}, 'link': '/v3/places/4a4560a7f964a5201aa81fe3', 'location': {'address': '2 Gold St', 'census_block': '360610015024001', 'country': 'US', 'cross_street': 'at Maiden Ln.', 'dma': 'New York', 'formatted_address': '2 Gold St (at Maiden Ln.), New York, NY 10038', 'locality': 'New York', 'neighborhood': ['City Hall'], 'postcode': '10038', 'region': 'NY'}, 'name': "Harry's Italian Pizza Bar", 'related_places': {}, 'timezone': 'America/New_York'}, {'fsq_id': '528bf16711d2b7722da6b51c', 'categories': [{'id'
# ...

# %% [markdown]
# #### Definir la URL correspondiente

# %%
url = "https://api.foursquare.com/v3/places/nearby?ll=40.7149555%2C-74.0153365&query=%27Italian%27&limit=30"
url
# Out:
# 'https://api.foursquare.com/v3/places/nearby?ll=40.7149555%2C-74.0153365&query=%27Italian%27&limit=30'

# %% [markdown]
# #### Enviar la petición GET y examinar los resultados

# %%
response = requests.get(url, headers=headers)
print('La respuesta es afirmativa de los datos: ' , response)
# Out:
# La respuesta es afirmativa de los datos:  <Response [200]>

# %% [markdown]
# #### Obtener la parte relevante del JSON y convertirlo en un dataframe *pandas*

# %%
data = {
  "results": [
    {
      "fsq_id": "4a4560a7f964a5201aa81fe3",
      "categories": [
        {
          "id": 13064,
          "name": "Pizzeria",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/pizza_",
            "suffix": ".png"
          }
        },
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 1074,
      "geocodes": {
        "main": {
          "latitude": 40.707324,
          "longitude": -74.007057
        },
        "roof": {
          "latitude": 40.707324,
          "longitude": -74.007057
        }
      },
      "link": "/v3/places/4a4560a7f964a5201aa81fe3",
      "location": {
        "address": "2 Gold St",
        "census_block": "360610015024001",
        "country": "US",
        "cross_street": "at Maiden Ln.",
        "dma": "New York",
        "formatted_address": "2 Gold St (at Maiden Ln.), New York, NY 10038",
        "locality": "New York",
        "neighborhood": [
          "City Hall"
        ],
        "postcode": "10038",
        "region": "NY"
      },
      "name": "Harry's Italian Pizza Bar",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "528bf16711d2b7722da6b51c",
      "categories": [
        {
          "id": 13002,
          "name": "Bakery",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/bakery_",
            "suffix": ".png"
          }
        },
        {
          "id": 13035,
          "name": "Coffee Shop",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
            "suffix": ".png"
          }
        },
        {
          "id": 13334,
          "name": "Sandwich Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/deli_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 821,
      "geocodes": {
        "main": {
          "latitude": 40.710597,
          "longitude": -74.007667
        },
        "roof": {
          "latitude": 40.710597,
          "longitude": -74.007667
        }
      },
      "link": "/v3/places/528bf16711d2b7722da6b51c",
      "location": {
        "address": "97 Nassau St",
        "census_block": "360610015011017",
        "country": "US",
        "cross_street": "at Ann St",
        "dma": "New York",
        "formatted_address": "97 Nassau St (at Ann St), New York, NY 10038",
        "locality": "New York",
        "neighborhood": [
          "City Hall"
        ],
        "postcode": "10038",
        "region": "NY"
      },
      "name": "Pisillo Italian Cafe",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4fa862b3e4b0ebff2f749f06",
      "categories": [
        {
          "id": 13064,
          "name": "Pizzeria",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/pizza_",
            "suffix": ".png"
          }
        },
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 58,
      "geocodes": {
        "main": {
          "latitude": 40.715256,
          "longitude": -74.014835
        },
        "roof": {
          "latitude": 40.715256,
          "longitude": -74.014835
        }
      },
      "link": "/v3/places/4fa862b3e4b0ebff2f749f06",
      "location": {
        "address": "225 Murray St",
        "census_block": "360610317033007",
        "country": "US",
        "dma": "New York",
        "formatted_address": "225 Murray St, New York, NY 10282",
        "locality": "New York",
        "neighborhood": [
          "Battery Park City"
        ],
        "postcode": "10282",
        "region": "NY"
      },
      "name": "Harry's Italian Pizza Bar",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4b9d4c67f964a5206ca136e3",
      "categories": [
        {
          "id": 10030,
          "name": "History Museum",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 1584,
      "geocodes": {
        "main": {
          "latitude": 40.719179,
          "longitude": -73.997531
        },
        "roof": {
          "latitude": 40.719179,
          "longitude": -73.997531
        }
      },
      "link": "/v3/places/4b9d4c67f964a5206ca136e3",
      "location": {
        "address": "155 Mulberry St",
        "census_block": "360610041005003",
        "country": "US",
        "cross_street": "at Grand St",
        "dma": "New York",
        "formatted_address": "155 Mulberry St (at Grand St), New York, NY 10013",
        "locality": "New York",
        "neighborhood": [
          "Chinatown"
        ],
        "postcode": "10013",
        "region": "NY"
      },
      "name": "Italian American Museum",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4e4c4e62bd413c4cc6686059",
      "categories": [
        {
          "id": 13064,
          "name": "Pizzeria",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/pizza_",
            "suffix": ".png"
          }
        },
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 1346,
      "geocodes": {
        "main": {
          "latitude": 40.703251,
          "longitude": -74.011015
        }
      },
      "link": "/v3/places/4e4c4e62bd413c4cc6686059",
      "location": {
        "address": "30 Water St",
        "census_block": "360610009001015",
        "country": "US",
        "dma": "New York",
        "formatted_address": "30 Water St, New York, NJ 10004",
        "locality": "New York",
        "neighborhood": [
          "Battery Park City"
        ],
        "postcode": "10004",
        "region": "NJ"
      },
      "name": "Carmela's Italian Specialties",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4f3feae2e4b0ac9416a72118",
      "categories": [
        {
          "id": 17068,
          "name": "Gourmet Store",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 594,
      "geocodes": {
        "main": {
          "latitude": 40.709703,
          "longitude": -74.016709
        },
        "roof": {
          "latitude": 40.709703,
          "longitude": -74.016709
        }
      },
      "link": "/v3/places/4f3feae2e4b0ac9416a72118",
      "location": {
        "address": "235 S End Ave",
        "census_block": "360610317042000",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "235 S End Ave, New York, NY 10280",
        "locality": "New York",
        "neighborhood": [
          "Battery Park City"
        ],
        "postcode": "10280",
        "region": "NY"
      },
      "name": "Benvenuti Italian Specialties",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "3fd66200f964a5209ee81ee3",
      "categories": [
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 5303,
      "geocodes": {
        "main": {
          "latitude": 40.757353,
          "longitude": -73.986368
        },
        "roof": {
          "latitude": 40.757353,
          "longitude": -73.986368
        }
      },
      "link": "/v3/places/3fd66200f964a5209ee81ee3",
      "location": {
        "address": "200 W 44th St",
        "address_extended": "# 1",
        "census_block": "360610119002003",
        "country": "US",
        "cross_street": "btwn Broadway & 8th Ave",
        "dma": "New York",
        "formatted_address": "200 W 44th St (btwn Broadway & 8th Ave), New York, NY 10036",
        "locality": "New York",
        "neighborhood": [
          "Midtown"
        ],
        "postcode": "10036",
        "region": "NY"
      },
      "name": "Carmine's",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4a74a36af964a520fede1fe3",
      "categories": [
        {
          "id": 13039,
          "name": "Deli",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/deli_",
            "suffix": ".png"
          }
        },
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        },
        {
          "id": 13334,
          "name": "Sandwich Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/deli_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 2072,
      "geocodes": {
        "main": {
          "latitude": 40.731003,
          "longitude": -74.003062
        },
        "roof": {
          "latitude": 40.731003,
          "longitude": -74.003062
        }
      },
      "link": "/v3/places/4a74a36af964a520fede1fe3",
      "location": {
        "address": "260 Bleecker St",
        "census_block": "360610067003001",
        "country": "US",
        "cross_street": "at Cornelia St",
        "dma": "New York",
        "formatted_address": "260 Bleecker St (at Cornelia St), New York, NY 10014",
        "locality": "New York",
        "neighborhood": [
          "Downtown"
        ],
        "postcode": "10014",
        "region": "NY"
      },
      "name": "Faicco's Italian Specialities",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4b269f5af964a520817e24e3",
      "categories": [
        {
          "id": 13002,
          "name": "Bakery",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/bakery_",
            "suffix": ".png"
          }
        },
        {
          "id": 13039,
          "name": "Deli",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/deli_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 3295,
      "geocodes": {
        "main": {
          "latitude": 40.739859,
          "longitude": -74.036296
        },
        "roof": {
          "latitude": 40.739859,
          "longitude": -74.036296
        }
      },
      "link": "/v3/places/4b269f5af964a520817e24e3",
      "location": {
        "address": "410 2nd St",
        "census_block": "340170191001002",
        "country": "US",
        "cross_street": "btw Grand St & Adams St",
        "dma": "New York",
        "formatted_address": "410 2nd St (btw Grand St & Adams St), Hoboken, NJ 07030",
        "locality": "Hoboken",
        "neighborhood": [
          "Downtown"
        ],
        "postcode": "07030",
        "region": "NJ"
      },
      "name": "Losurdo's Italian Bakery & Deli",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4f3232e219836c91c7bfde94",
      "categories": [
        {
          "id": 13064,
          "name": "Pizzeria",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/pizza_",
            "suffix": ".png"
          }
        },
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        },
        {
          "id": 13302,
          "name": "Mediterranean Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/mediterranean_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 468,
      "geocodes": {
        "main": {
          "latitude": 40.714419,
          "longitude": -74.009913
        },
        "roof": {
          "latitude": 40.714419,
          "longitude": -74.009913
        }
      },
      "link": "/v3/places/4f3232e219836c91c7bfde94",
      "location": {
        "address": "63 W Broadway",
        "census_block": "360610021001006",
        "country": "US",
        "dma": "New York",
        "formatted_address": "63 W Broadway, New York, NY 10007",
        "locality": "New York",
        "neighborhood": [
          "Battery Park City"
        ],
        "postcode": "10007",
        "region": "NY"
      },
      "name": "Conca Cucina Italiana",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "58dd8ac3a8b75966fda9a547",
      "categories": [
        {
          "id": 13025,
          "name": "Wine Bar",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/winery_",
            "suffix": ".png"
          }
        },
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        },
        {
          "id": 13302,
          "name": "Mediterranean Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/mediterranean_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 2748,
      "geocodes": {
        "main": {
          "latitude": 40.726759,
          "longitude": -73.986523
        },
        "roof": {
          "latitude": 40.726759,
          "longitude": -73.986523
        }
      },
      "link": "/v3/places/58dd8ac3a8b75966fda9a547",
      "location": {
        "address": "345 E 6th St",
        "census_block": "360610038006000",
        "country": "US",
        "cross_street": "1st and 2nd Ave",
        "dma": "New York",
        "formatted_address": "345 E 6th St (1st and 2nd Ave), New York, NY 10003",
        "locality": "New York",
        "neighborhood": [
          "Downtown"
        ],
        "postcode": "10003",
        "region": "NY"
      },
      "name": "Tableside Italian Cook Shoppe",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "5400c682498e3831aaada9fc",
      "categories": [
        {
          "id": 13064,
          "name": "Pizzeria",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/pizza_",
            "suffix": ".png"
          }
        },
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 2392,
      "geocodes": {
        "main": {
          "latitude": 40.720534,
          "longitude": -74.042634
        },
        "roof": {
          "latitude": 40.720534,
          "longitude": -74.042634
        }
      },
      "link": "/v3/places/5400c682498e3831aaada9fc",
      "location": {
        "address": "346 Grove St",
        "census_block": "340170070022002",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "346 Grove St, Jersey City, NJ 07302",
        "locality": "Jersey City",
        "neighborhood": [
          "Battery Park City"
        ],
        "postcode": "07302",
        "region": "NJ"
      },
      "name": "Alex's Italian Restaurant & Brick Oven Pizza",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "51e7310c498e639ed27062b1",
      "categories": [
        {
          "id": 13065,
          "name": "Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 6390,
      "geocodes": {
        "main": {
          "latitude": 40.764411,
          "longitude": -73.976771
        },
        "roof": {
          "latitude": 40.764411,
          "longitude": -73.976771
        }
      },
      "link": "/v3/places/51e7310c498e639ed27062b1",
      "location": {
        "address": "57 W 57th St",
        "census_block": "360610112011002",
        "country": "US",
        "cross_street": "at 6th Ave",
        "dma": "New York",
        "formatted_address": "57 W 57th St (at 6th Ave), New York, NY 10019",
        "locality": "New York",
        "neighborhood": [
          "East Side"
        ],
        "postcode": "10019",
        "region": "NY"
      },
      "name": "Quality Italian",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "60849f4791710d12f73810b7",
      "categories": [
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 2904,
      "geocodes": {
        "main": {
          "latitude": 40.722153,
          "longitude": -73.982185
        }
      },
      "link": "/v3/places/60849f4791710d12f73810b7",
      "location": {
        "address": "226 E 3rd St",
        "census_block": "360610022021001",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "226 E 3rd St, New York, NY 10009",
        "locality": "New York",
        "neighborhood": [
          "Alphabet City"
        ],
        "postcode": "10009",
        "region": "NY"
      },
      "name": "Gaia Italian Café",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "49fa194ff964a520bb6d1fe3",
      "categories": [
        {
          "id": 13046,
          "name": "Ice Cream Parlor",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
            "suffix": ".png"
          }
        },
        {
          "id": 13068,
          "name": "American Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [
        {
          "id": "9632dc81-7fb6-4833-84f0-539bf06a7657",
          "name": "Rita's Italian Ice"
        }
      ],
      "distance": 2880,
      "geocodes": {
        "main": {
          "latitude": 40.73813,
          "longitude": -74.030506
        },
        "roof": {
          "latitude": 40.73813,
          "longitude": -74.030506
        }
      },
      "link": "/v3/places/49fa194ff964a520bb6d1fe3",
      "location": {
        "address": "121 Washington St",
        "address_extended": "Ste A",
        "census_block": "340170194002005",
        "country": "US",
        "cross_street": "by 1st",
        "dma": "New York",
        "formatted_address": "121 Washington St (by 1st), Hoboken, NJ 07030",
        "locality": "Hoboken",
        "neighborhood": [
          "Downtown"
        ],
        "postcode": "07030",
        "region": "NJ"
      },
      "name": "Rita's Italian Ice",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4e4c4d28bd413c4cc66857a5",
      "categories": [
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 773,
      "geocodes": {
        "main": {
          "latitude": 40.710583,
          "longitude": -74.00819
        },
        "roof": {
          "latitude": 40.710583,
          "longitude": -74.00819
        }
      },
      "link": "/v3/places/4e4c4d28bd413c4cc66857a5",
      "location": {
        "address": "42 Broadway",
        "census_block": "360610015011017",
        "country": "US",
        "dma": "New York",
        "formatted_address": "42 Broadway, New York, NY 10004",
        "locality": "New York",
        "neighborhood": [
          "City Hall"
        ],
        "postcode": "10004",
        "region": "NY"
      },
      "name": "Caruso's Italian Restaurant",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "6065ecdcc85e724bffef8c08",
      "categories": [
        {
          "id": 13034,
          "name": "Café",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 815,
      "geocodes": {
        "main": {
          "latitude": 40.710458,
          "longitude": -74.007693
        }
      },
      "link": "/v3/places/6065ecdcc85e724bffef8c08",
      "location": {
        "address": "99 Nassau St",
        "census_block": "360610015011017",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "99 Nassau St, New York, NY 10038",
        "locality": "New York",
        "neighborhood": [
          "City Hall"
        ],
        "postcode": "10038",
        "region": "NY"
      },
      "name": "Pisillo Italian Cafe",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4c3b8244def90f478f0ffe2d",
      "categories": [
        {
          "id": 17043,
          "name": "Clothing Store",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/apparel_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 899,
      "geocodes": {
        "main": {
          "latitude": 40.707842,
          "longitude": -74.009827
        },
        "roof": {
          "latitude": 40.707842,
          "longitude": -74.009827
        }
      },
      "link": "/v3/places/4c3b8244def90f478f0ffe2d",
      "location": {
        "address": "120 Broadway",
        "census_block": "360610007003000",
        "country": "US",
        "cross_street": "btw Cedar & Pine",
        "dma": "New York",
        "formatted_address": "120 Broadway (btw Cedar & Pine), New York, NY 10271",
        "locality": "New York",
        "neighborhood": [
          "Downtown"
        ],
        "postcode": "10271",
        "region": "NY"
      },
      "name": "Barber Italian Shop",
      "related_places": {
        "parent": {
          "fsq_id": "4b3a5cabf964a520926525e3",
          "name": "Equitable Building"
        }
      },
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4c6d6619e6b7b1f7ef98a98e",
      "categories": [
        {
          "id": 11124,
          "name": "Office",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/building/default_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 5621,
      "geocodes": {
        "main": {
          "latitude": 40.754038,
          "longitude": -73.973221
        },
        "roof": {
          "latitude": 40.754038,
          "longitude": -73.973221
        }
      },
      "link": "/v3/places/4c6d6619e6b7b1f7ef98a98e",
      "location": {
        "address": "750 3rd Ave",
        "census_block": "360610092003002",
        "country": "US",
        "cross_street": "btw E 46th & 47th St",
        "dma": "New York",
        "formatted_address": "750 3rd Ave (btw E 46th & 47th St), New York, NY 10017",
        "locality": "New York",
        "neighborhood": [
          "East Side"
        ],
        "postcode": "10017",
        "region": "NY"
      },
      "name": "Italian Vogue",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4f8b1243e4b0183207522489",
      "categories": [
        {
          "id": 13046,
          "name": "Ice Cream Parlor",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
            "suffix": ".png"
          }
        },
        {
          "id": 13065,
          "name": "Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 7818,
      "geocodes": {
        "main": {
          "latitude": 40.650669,
          "longitude": -73.97718
        },
        "roof": {
          "latitude": 40.650669,
          "longitude": -73.97718
        }
      },
      "link": "/v3/places/4f8b1243e4b0183207522489",
      "location": {
        "address": "422 Greenwood Ave",
        "census_block": "360470500012001",
        "country": "US",
        "cross_street": "at E 5th St",
        "dma": "New York",
        "formatted_address": "422 Greenwood Ave (at E 5th St), Brooklyn, NY 11218",
        "locality": "Brooklyn",
        "neighborhood": [
          "Kensington"
        ],
        "postcode": "11218",
        "region": "NY"
      },
      "name": "Kathy's Gourmet Italian Ices & Ice Cream",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "5c893ef0d8096e0039e7363b",
      "categories": [
        {
          "id": 13039,
          "name": "Deli",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/deli_",
            "suffix": ".png"
          }
        },
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        },
        {
          "id": 13334,
          "name": "Sandwich Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/deli_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 3795,
      "geocodes": {
        "main": {
          "latitude": 40.744441,
          "longitude": -73.992937
        },
        "roof": {
          "latitude": 40.744441,
          "longitude": -73.992937
        }
      },
      "link": "/v3/places/5c893ef0d8096e0039e7363b",
      "location": {
        "address": "124 W 25th St",
        "census_block": "360610091005001",
        "country": "US",
        "cross_street": "btwn 6th & 7th Ave",
        "dma": "New York",
        "formatted_address": "124 W 25th St (btwn 6th & 7th Ave), New York, NY 10001",
        "locality": "New York",
        "neighborhood": [
          "Chelsea"
        ],
        "postcode": "10001",
        "region": "NY"
      },
      "name": "Pisillo Italian Panini",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4b687882f964a520a67a2be3",
      "categories": [
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 1226,
      "geocodes": {
        "main": {
          "latitude": 40.705179,
          "longitude": -74.008587
        },
        "roof": {
          "latitude": 40.705179,
          "longitude": -74.008587
        }
      },
      "link": "/v3/places/4b687882f964a520a67a2be3",
      "location": {
        "address": "82 Beaver St",
        "census_block": "360610007006001",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "82 Beaver St, New York, NY 10005",
        "locality": "New York",
        "neighborhood": [
          "Downtown"
        ],
        "postcode": "10005",
        "region": "NY"
      },
      "name": "Fino Ristorante Italiano",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4b6c4ebaf964a520612f2ce3",
      "categories": [
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 4382,
      "geocodes": {
        "main": {
          "latitude": 40.744652,
          "longitude": -73.981154
        },
        "roof": {
          "latitude": 40.744652,
          "longitude": -73.981154
        }
      },
      "link": "/v3/places/4b6c4ebaf964a520612f2ce3",
      "location": {
        "address": "182 Lexington Ave",
        "census_block": "360610072002002",
        "country": "US",
        "cross_street": "btw 31st & 32nd",
        "dma": "New York",
        "formatted_address": "182 Lexington Ave (btw 31st & 32nd), New York, NY 10016",
        "locality": "New York",
        "neighborhood": [
          "East Side"
        ],
        "postcode": "10016",
        "region": "NY"
      },
      "name": "Olive Tree",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "51fbf7a3498e86b46099a568",
      "categories": [
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 1290,
      "geocodes": {
        "main": {
          "latitude": 40.703658,
          "longitude": -74.012977
        },
        "roof": {
          "latitude": 40.703658,
          "longitude": -74.012977
        }
      },
      "link": "/v3/places/51fbf7a3498e86b46099a568",
      "location": {
        "address": "Whitehall St",
        "census_block": "360610009001023",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "Whitehall St, New York, NY 10004",
        "locality": "New York",
        "neighborhood": [
          "Battery Park City"
        ],
        "postcode": "10004",
        "region": "NY"
      },
      "name": "Dominic's Italian Sausage",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4f779e12e4b08e5a67d80bb4",
      "categories": [
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 1313,
      "geocodes": {
        "main": {
          "latitude": 40.722415,
          "longitude": -74.003465
        },
        "roof": {
          "latitude": 40.722415,
          "longitude": -74.003465
        }
      },
      "link": "/v3/places/4f779e12e4b08e5a67d80bb4",
      "location": {
        "address": "341 W Broadway",
        "census_block": "360610047002006",
        "country": "US",
        "cross_street": "None",
        "dma": "New York",
        "formatted_address": "341 W Broadway (None), New York, NY 10013",
        "locality": "New York",
        "neighborhood": [
          "Chinatown"
        ],
        "postcode": "10013",
        "region": "NY"
      },
      "name": "Diva italian resturant",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4ba00318f964a520285237e3",
      "categories": [
        {
          "id": 12013,
          "name": "College and University",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/education/default_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 11290,
      "geocodes": {
        "main": {
          "latitude": 40.807551,
          "longitude": -73.960306
        },
        "roof": {
          "latitude": 40.807551,
          "longitude": -73.960306
        }
      },
      "link": "/v3/places/4ba00318f964a520285237e3",
      "location": {
        "address": "1161 Amsterdam Ave",
        "census_block": "360610201011000",
        "country": "US",
        "cross_street": "West 118th Street",
        "dma": "New York",
        "formatted_address": "1161 Amsterdam Ave (West 118th Street), New York, NY 10027",
        "locality": "New York",
        "neighborhood": [
          "Harlem"
        ],
        "postcode": "10027",
        "region": "NY"
      },
      "name": "Italian Academy",
      "related_places": {
        "parent": {
          "fsq_id": "4227a500f964a520c51f1fe3",
          "name": "Columbia University"
        }
      },
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4a90dbbef964a520a11920e3",
      "categories": [
        {
          "id": 13064,
          "name": "Pizzeria",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/pizza_",
            "suffix": ".png"
          }
        },
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 8182,
      "geocodes": {
        "main": {
          "latitude": 40.772789,
          "longitude": -73.952146
        },
        "roof": {
          "latitude": 40.772789,
          "longitude": -73.952146
        }
      },
      "link": "/v3/places/4a90dbbef964a520a11920e3",
      "location": {
        "address": "1526 1st Ave",
        "address_extended": "Frnt 1",
        "census_block": "360610136031000",
        "country": "US",
        "cross_street": "79th and 1st",
        "formatted_address": "1526 1st Ave (79th and 1st), New York, NY 10075",
        "locality": "New York",
        "neighborhood": [
          "Upper East Side"
        ],
        "postcode": "10075",
        "region": "NY"
      },
      "name": "Italian Village Pizzeria & Restaurant",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4b5a413ff964a520cfb728e3",
      "categories": [
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        },
        {
          "id": 13334,
          "name": "Sandwich Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/deli_",
            "suffix": ".png"
          }
        },
        {
          "id": 17077,
          "name": "Meat and Seafood Store",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 10205,
      "geocodes": {
        "main": {
          "latitude": 40.762156,
          "longitude": -73.911589
        },
        "roof": {
          "latitude": 40.762156,
          "longitude": -73.911589
        }
      },
      "link": "/v3/places/4b5a413ff964a520cfb728e3",
      "location": {
        "address": "4416 30th Ave",
        "census_block": "360810151002000",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "4416 30th Ave, Astoria, NY 11103",
        "locality": "Astoria",
        "neighborhood": [
          "Astoria"
        ],
        "postcode": "11103",
        "region": "NY"
      },
      "name": "Sorriso Italian Pork Store",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "5db3489e5fd6fb00082d7f39",
      "categories": [
        {
          "id": 11086,
          "name": "General Contractor",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/realestate_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 11223,
      "geocodes": {
        "main": {
          "latitude": 40.615176,
          "longitude": -73.994612
        },
        "roof": {
          "latitude": 40.615176,
          "longitude": -73.994612
        }
      },
      "link": "/v3/places/5db3489e5fd6fb00082d7f39",
      "location": {
        "address": "7202 18th Ave",
        "census_block": "360470264001001",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "7202 18th Ave, Brooklyn, NY 11204",
        "locality": "Brooklyn",
        "neighborhood": [
          "Bensonhurst"
        ],
        "postcode": "11204",
        "region": "NY"
      },
      "name": "Italian Tile Imports",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4a7778a1f964a5209be41fe3",
      "categories": [
        {
          "id": 13236,
          "name": "Italian Restaurant",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [],
      "distance": 9149,
      "geocodes": {
        "main": {
          "latitude": 40.790985,
          "longitude": -73.974092
        },
        "roof": {
          "latitude": 40.790985,
          "longitude": -73.974092
        }
      },
      "link": "/v3/places/4a7778a1f964a5209be41fe3",
      "location": {
        "address": "2450 Broadway",
        "census_block": "360610179007002",
        "country": "US",
        "cross_street": "btwn W 90th & W 91st",
        "dma": "New York",
        "formatted_address": "2450 Broadway (btwn W 90th & W 91st), New York, NY 10024",
        "locality": "New York",
        "neighborhood": [
          "Upper West Side"
        ],
        "postcode": "10024",
        "region": "NY"
      },
      "name": "Carmine's",
      "related_places": {},
      "timezone": "America/New_York"
    }
  ]
}
df_dataframe = []
from unicodedata import category
import pandas as pd
result = data['results']
for entry in result:
    name = entry["name"]
    category = entry["categories"][0]['name']
    geocode_dct = entry['geocodes']['main']
    lat = geocode_dct['latitude']
    lon = geocode_dct['longitude']

    df_dataframe.append({
        "name": name,
        "lat": lat,
        "lon": lon,
        "category": category
    })
df = pd.DataFrame(df_dataframe)
print(df)
# Out:
#                                             name        lat        lon  \
# 0                      Harry's Italian Pizza Bar  40.707324 -74.007057
# 1                           Pisillo Italian Cafe  40.710597 -74.007667
# 2                      Harry's Italian Pizza Bar  40.715256 -74.014835
# 3                        Italian American Museum  40.719179 -73.997531
# 4                  Carmela's Italian Specialties  40.703251 -74.011015
# 5                  Benvenuti Italian Specialties  40.709703 -74.016709
# 6                                      Carmine's  40.757353 -73.986368
# 7                  Faicco's Italian Specialities  40.731003 -74.003062
# 8                Losurdo's Italian Bakery & Deli  40.739859 -74.036296
# 9                          Conca Cucina Italiana  40.714419 -74.009913
# 10                 Tableside Italian Cook Shoppe  40.726759 -73.986523
# 11  Alex's Italian Restaurant & Brick Oven Pizza  40.720534 -74.042634
# ...

# %%
import folium # librería para graficar 
m = folium.Map(location=[lat, lon], zoom_start=15) # generate map centred around the Conrad Hotel

tooltip='Conrad Hotel'

# añadir un circulo rojo que represente el Hotel Conrad
folium.Marker(
    [lat, lon],
    #radius=10,
    #color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6,
    tooltip=tooltip
        
).add_to(m)

# añadir los restaurantes italianos como circulo azules
for lat, lon, label in zip(df.lat, df.lon, df.category):
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(m)
    

# mostrar el mapa
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# añadir los restaurantes italianos como circulo azules
m1 = folium.Map(location=[lat, lon], zoom_start=10, tiles="Stamen Terrain")
for lat, lon, label in zip(df.lat, df.lon, df.name):
    folium.CircleMarker(
        [lat, lon],
        radius=6,
        color='red',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(m1)
    
# mostrar el mapa
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Visualicemos los restaurantes italianos cercanos

# %%
df_filtered.name
# Out:
#                                             name  \
# 0                      Harry's Italian Pizza Bar
# 1                           Pisillo Italian Cafe
# 2                      Harry's Italian Pizza Bar
# 3                        Italian American Museum
# 4                  Carmela's Italian Specialties
# 5                  Benvenuti Italian Specialties
# 6                                      Carmine's
# 7                  Faicco's Italian Specialities
# 8                Losurdo's Italian Bakery & Deli
# 9                          Conca Cucina Italiana
# 10                 Tableside Italian Cook Shoppe
# 11  Alex's Italian Restaurant & Brick Oven Pizza
# 12                               Quality Italian
# 13                             Gaia Italian Café
# 14                            Rita's Italian Ice
# 15                   Caruso's Italian Restaurant
# 16                          Pisillo Italian Cafe
# 17                           Barber Italian Shop
# ...

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# ## 2. Explorar un Lugar Dado
#
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### A. Investiguemos el restaurante italiano mas cercano -- *Harry's Italian Pizza Bar*

# %%
venue_id = '4fa862b3e4b0ebff2f749f06' # ID of Harry's Italian Pizza Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4fa862b3e4b0ebff2f749f06?client_id=JH4PNBUYQL4VQOVJNTCSWLFDQBPNVZTSWKC5UTWXNKNJMH20&client_secret=KIP3WV5SAR3G2XNAKEVKKAXFRK2KRWYM1XEF4CPGCJYWLMA5&v=20200418'

# %% [markdown]
# #### Enviar la petición GET y examinar los resultados

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_71/645282592.py in <module>
#       1 result = requests.get(url).json()
# ----> 2 print(result['response']['venue'].keys())
#       3 result['response']['venue']
#
# KeyError: 'venue'

# %% [markdown]
# ### B. Obtener la puntuación general del lugar

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# No es una puntuación muy buena. Revisemos la puntuación del siguiente restaurante italiano mas cercano.

# %%
venue_id = '4f3232e219836c91c7bfde94' # ID del Restaurante Conca Cucina Italian
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Debido a que este restaurante no tiene puntuación, revisemos un tercero

# %%
venue_id = '3fd66200f964a520f4e41ee3' # ID de Ecco
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Este restaurante tiene un puntuación ligeramente mejor, revisemosla con mas detalle.

# %% [markdown]
# ### C. Obtener el número de consejos

# %%
result['response']['venue']['tips']['count']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_71/570850126.py in <module>
# ----> 1 result['response']['venue']['tips']['count']
#
# KeyError: 'venue'

# %% [markdown]
# ### D. Obtener los consejos de un lugar
#
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`/tips?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### Generar una URL y enviar una solicitud GET. Asegúrese de establecer el límite para obtener todos los consejos

# %%
## Consejos de Ecco
limit = 15 # establece el límite para ser mayor o igual al número total de consejos
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results

# %% [markdown]
# #### Obtener consejos y la lista de características asociadas

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_71/244820811.py in <module>
# ----> 1 tips = results['response']['tips']['items']
#       2
#       3 tip = results['response']['tips']['items'][0]
#       4 tip.keys()
#
# KeyError: 'tips'

# %% [markdown]
# #### Dar formato al ancho de la columna y mostrar todos los consejos

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # consejos json normalizados

# columnas a mantener
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# mostrar consejos
tips_filtered.reindex()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_71/810770697.py in <module>
#       1 pd.set_option('display.max_colwidth', -1)
#       2
# ----> 3 tips_df = json_normalize(tips) # consejos json normalizados
#       4
#       5 # columnas a mantener
#
# NameError: name 'tips' is not defined

# %% [markdown]
# Recuerde que debido a que estamos usando una cuenta personal de desarrollador solo podemos acceder a 2 de los 15 consejos del restaurante.

# %% [markdown]
# <a id="item3"></a>

# %% [markdown]
# ## 3. Buscar a un Usuario de FourSquare
#
# > `https://api.foursquare.com/v2/users/`**USER_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### Definir la URL, enviar la solicitud GET y mostrar las características asociadas con el usuario

# %%
idnumber = '48454224' # ID del usuario con mayor número de aceptación y perfil completo 

url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}'.format(idnumber, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# enviar solicitud GET
results = requests.get(url).json()
#user_data = results['response']['user']
user_data=results['response']['tips']['items'][0]['venue']['photos']['groups'][0]['items']#['items']
# mostrar características asociadas con el usuario
#user_data.keys()
#results
pd.set_option('display.max_colwidth', -1)

users_df = json_normalize(user_data)

# filtrar columnas
filtered_columns = ['id','user.id','user.firstName','user.lastName']
tips_filtered = users_df.loc[:, filtered_columns]

# mostrar consejos del usuario
df=tips_filtered
df
#url
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   if sys.path[0] == "":
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_71/2424449270.py in <module>
#      16 # filtrar columnas
#      17 filtered_columns = ['id','user.id','user.firstName','user.lastName']
# ---> 18 tips_filtered = users_df.loc[:, filtered_columns]
#      19
#      20 # mostrar consejos del usuario
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
# ...

# %%
g=df.loc[df['user.id'] == '133773133']
print('First Name: ' + g['user.firstName'])
print('Last Name: ' + g['user.lastName'])

# %% [markdown]
# ### Obtener la Imagen del Perfil del Usuario

# %%
# 1. tomar el prefijo de la foto
# 2. tomar el sufijo de la foto
# 3. concatenarlos utilizando el tamaño de la imagen
Image(url='https://fastly.4sqi.net/img/general/540x920/133773133_ODR5Au05ENkSyu3xxfV3VOfCa0idDfm9Q4n8YbhZDRQ.jpg')

# %% [markdown]
# ¡Wow! Parece ser que Nick es un usuario muy activo en FourSquare con mas de 250 consejos.

# %% [markdown]
# ### Obtener las Recomendaciones del usuario

# %%
# definir la URL de las recomendaciones
user_id='484542633'
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

# enviar la solicitud GET y obtener las recomendaciones del usuario
results = requests.get(url).json()
tips = results['response']['tips']['items']

# dar formato al ancho de la columna
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filtrar columnas
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# mostrar las recomendaciones del usuario
tips_filtered

# %% [markdown]
# #### Obtengamos el lugar para la recomendación con el mayor número de aceptaciones

# %%
tip_id = '5ab5575d73fe2516ad8f363b' # id de la recomendación

# definir la URL
url = 'http://api.foursquare.com/v2/tips/{}?client_id={}&client_secret={}&v={}'.format(tip_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# enviar la solicitud GET y examinar los resultados
result = requests.get(url).json()
print(result['response']['tip']['venue']['name'])
print(result['response']['tip']['venue']['location'])

# %% [markdown]
# ## 4. Explorar una Ubicación
#
# > `https://api.foursquare.com/v2/venues/`**explore**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### Ha definido su platillo gourmet en Ecco y siente curiosidad acerca de los sitios populares alrededor del restaurante. Para explorar el área, empecemos por obtener los valores de latitud y la longitud del Restaurant Ecco.

# %%
latitude = 40.715337
longitude = -74.008848

# %% [markdown]
# #### Definir una URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url

# %% [markdown]
# #### Enviar una solicitud GET y examinar los resultados

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items']))

# %% [markdown]
# #### Obtener la parte relevante del objeto JSON

# %%
items = results['response']['groups'][0]['items']
items[0]

# %% [markdown]
# #### Procesar el objeto JSON, convetirlo y limpiar el dataframe

# %%
dataframe = json_normalize(items) # JSON

# filtrar columnas
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filtrar la categoría para cada columna
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# limpiar columnas
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)

# %% [markdown]
# #### Visualicemos estos elementos en el mapa alrededor de nuestra ubicación

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# Añadir Ecco como una marca circular roja
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# añadir sitios populares al mapa como marcas circulares azules
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# mostrar mapa
venues_map

# %% [markdown]
# <a id="item5"></a>

# %% [markdown]
# ## 5. Explorar Sitios Populares
#
# > `https://api.foursquare.com/v2/venues/`**trending**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**

# %% [markdown]
# #### Ahora, en vez de explorar  el área alrededor de Ecco, es de interes saber los sitios que son populares durante su comida, esto es, los lugares con el mayor tráfico peatonal. Hagamoslo y obtengamos los sitios populares alrededor de Ecco.

# %%
# definir la URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# enviar la solicitud GET y obtener los sitios de moda
results = requests.get(url).json()
results

# %% [markdown]
# ### Revisar si algún sitio esta de moda en este momento

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filtrar columnas
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filtrar la categoría para cada fila
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# mostrar los sitios populares
trending_venues_df

# %% [markdown]
# Ahora, dependiendo de cuando usted ejecute el codigo anterior, podría obtener distintos sitios ya que la información de tráfico peatonal se obtiene en tiempo real.

# %% [markdown]
# ### Visuaizar sitios populares

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # añadir Ecco como una marca circular roja
    folium.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # añadir los sitios populares como marcas circulares azules
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# mostrar el mapa
venues_map

# %% [markdown]
# <a id="item6"></a>

# %% [markdown]
# ### Gracias por terminar este laboratorio
#
# Este cuaderno fue creado por [Alex Aklson](https://www.linkedin.com/in/aklson?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDS0701ESCoursera21685115-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ). Espero que haya encontrado este laboratorio de su interes y educativo. Tómese la libertad de contactar conmigo para cualquier duda o aclaración.
#
# Este cuaderno fue modificado por Nayef Abou Tayoun ([https://www.linkedin.com/in/nayefaboutayoun/](https://www.linkedin.com/in/nayefaboutayoun?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDS0701ESCoursera21685115-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ))

# %% [markdown]
# Este cuaderno forma parte del curso en **Coursera** llamado *Applied Data Science Capstone*. Si accede a este cuaderno desde afuera del curso, puede tomarlo en línea haciendo clic [aquí](http://cocl.us/DP0701EN_Coursera_Week2\_LAB1).

# %% [markdown]
# <hr>
# Copyright &copy; 2018 [Cognitive Class](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
